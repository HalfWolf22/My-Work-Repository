# %%
import numpy as np
import pandas as pd
import easydatascience as eds
import os
        
match_cols = ['MatchID', 'GameDuration', 'Blue_Won', 'Blue_KillsTower', 
              'Blue_KillsInhib', 'Blue_KillsBaron', 'Blue_KillsDragon', 
              'Purp_KillsTower', 'Purp_KillsInhib', 'Purp_KillsBaron',
              'Purp_KillsDragon']

base_player_cols = ['ChampionID', 'Kills', 'Deaths', 'Assists', 'Gold', 'CS', 'Role',
                    'Lane']

# Generating column names for 10 players
player_cols = []

for i in range(1, 11):
    curr_player = 'player' + str(i)
    curr_list = [curr_player + '_' + col for col in base_player_cols]
    player_cols += curr_list
    
column_names = match_cols + player_cols

# Reading CSVs
datas = []
csvs = [i for i in os.listdir() if i[-4:]=='.csv']

for csv in csvs:
    datas.append(pd.read_csv(csv, names=column_names))
    
data = pd.concat(datas)

data = data.reset_index(drop=True)

pd.set_option('max_rows', eds.look(data).shape[0])
eds.look(data)
# Out:
#                       Types  Counts  Distincts  Nulls  Missing ratio (%)  \
# MatchID              object   25582      25470      0                0.0
# GameDuration         object   25582       1432      0                0.0
# Blue_Won             object   25582          2      0                0.0
# Blue_KillsTower      object   25582         12      0                0.0
# Blue_KillsInhib      object   25582         10      0                0.0
# Blue_KillsBaron      object   25582          5      0                0.0
# Blue_KillsDragon     object   25582          8      0                0.0
# Purp_KillsTower      object   25582         12      0                0.0
# Purp_KillsInhib      object   25582         10      0                0.0
# Purp_KillsBaron      object   25582          5      0                0.0
# Purp_KillsDragon     object   25582          8      0                0.0
# player1_ChampionID   object   25582        150      0                0.0
# player1_Kills        object   25582         39      0                0.0
# player1_Deaths       object   25582         26      0                0.0
# player1_Assists      object   25582         45      0                0.0
# player1_Gold         object   25582      10916      0                0.0
# player1_CS           object   25582        352      0                0.0
# player1_Role         object   25582          5      0                0.0
# player1_Lane         object   25582          4      0                0.0
# player2_ChampionID   object   25582        150      0                0.0
# player2_Kills        object   25582         41      0                0.0
# player2_Deaths       object   25582         26      0                0.0
# player2_Assists      object   25582         42      0                0.0
# player2_Gold         object   25582      10915      0                0.0
# player2_CS           object   25582        352      0                0.0
# player2_Role         object   25582          5      0                0.0
# player2_Lane         object   25582          4      0                0.0
# player3_ChampionID   object   25582        150      0                0.0
# player3_Kills        object   25582         39      0                0.0
# player3_Deaths       object   25582         24      0                0.0
# player3_Assists      object   25582         42      0                0.0
# player3_Gold         object   25582      10860      0                0.0
# player3_CS           object   25582        354      0                0.0
# player3_Role         object   25582          5      0                0.0
# player3_Lane         object   25582          4      0                0.0
# player4_ChampionID   object   25582        150      0                0.0
# player4_Kills        object   25582         36      0                0.0
# player4_Deaths       object   25582         26      0                0.0
# player4_Assists      object   25582         44      0                0.0
# player4_Gold         object   25582      10929      0                0.0
# player4_CS           object   25582        353      0                0.0
# player4_Role         object   25582          5      0                0.0
# player4_Lane         object   25582          4      0                0.0
# player5_ChampionID   object   25582        150      0                0.0
# player5_Kills        object   25582         40      0                0.0
# player5_Deaths       object   25582         25      0                0.0
# player5_Assists      object   25582         43      0                0.0
# player5_Gold         object   25582      10924      0                0.0
# player5_CS           object   25582        347      0                0.0
# player5_Role         object   25582          5      0                0.0
# player5_Lane         object   25582          4      0                0.0
# player6_ChampionID   object   25582        150      0                0.0
# player6_Kills        object   25582         36      0                0.0
# player6_Deaths       object   25582         23      0                0.0
# player6_Assists      object   25582         43      0                0.0
# player6_Gold         object   25582      10892      0                0.0
# player6_CS           object   25582        358      0                0.0
# player6_Role         object   25582          5      0                0.0
# player6_Lane         object   25582          4      0                0.0
# player7_ChampionID   object   25582        150      0                0.0
# player7_Kills        object   25582         38      0                0.0
# player7_Deaths       object   25582         24      0                0.0
# player7_Assists      object   25582         43      0                0.0
# player7_Gold         object   25582      11011      0                0.0
# player7_CS           object   25582        353      0                0.0
# player7_Role         object   25582          5      0                0.0
# player7_Lane         object   25582          4      0                0.0
# player8_ChampionID   object   25582        150      0                0.0
# player8_Kills        object   25582         37      0                0.0
# player8_Deaths       object   25582         25      0                0.0
# player8_Assists      object   25582         41      0                0.0
# player8_Gold         object   25582      10957      0                0.0
# player8_CS           object   25582        359      0                0.0
# player8_Role         object   25582          5      0                0.0
# player8_Lane         object   25582          4      0                0.0
# player9_ChampionID   object   25582        150      0                0.0
# player9_Kills        object   25582         39      0                0.0
# player9_Deaths       object   25582         24      0                0.0
# player9_Assists      object   25582         45      0                0.0
# player9_Gold         object   25582      10940      0                0.0
# player9_CS           object   25582        349      0                0.0
# player9_Role         object   25582          5      0                0.0
# player9_Lane         object   25582          4      0                0.0
# player10_ChampionID  object   25582        150      0                0.0
# player10_Kills       object   25582         38      0                0.0
# player10_Deaths      object   25582         23      0                0.0
# player10_Assists     object   25582         44      0                0.0
# player10_Gold        object   25582      10957      0                0.0
# player10_CS          object   25582        352      0                0.0
# player10_Role        object   25582          5      0                0.0
# player10_Lane        object   25582          4      0                0.0
#
#                                                                Uniques  \
# MatchID              [[2554403479, 2560068908, 2559895973, 25590346...
# GameDuration         [[1573, 2214, 1964, 1681, 2403, 1553, 2330, 16...
# Blue_Won                                                 [[Fail, Win]]
# Blue_KillsTower               [[1, 6, 3, 0, 9, 7, 2, 5, 10, 11, 8, 4]]
# Blue_KillsInhib                       [[0, 1, 3, 2, 4, 6, 7, 5, 9, 8]]
# Blue_KillsBaron                                      [[0, 1, 2, 3, 4]]
# Blue_KillsDragon                            [[1, 3, 2, 0, 4, 5, 6, 7]]
# Purp_KillsTower               [[8, 7, 6, 11, 4, 2, 5, 10, 9, 1, 3, 0]]
# Purp_KillsInhib                      [[1, 3, 0, 2, 4, 5, 6, 7, 8, 10]]
# Purp_KillsBaron                                      [[1, 0, 2, 3, 4]]
# Purp_KillsDragon                            [[2, 4, 3, 1, 0, 5, 6, 7]]
# player1_ChampionID   [[35, 8, 267, 39, 115, 28, 29, 43, 777, 6, 119...
# player1_Kills        [[4, 1, 0, 8, 18, 6, 11, 3, 9, 13, 2, 5, 7, 14...
# player1_Deaths       [[5, 10, 9, 13, 12, 4, 0, 3, 7, 6, 8, 11, 2, 1...
# player1_Assists      [[4, 7, 6, 1, 18, 2, 9, 8, 5, 15, 14, 3, 17, 1...
# player1_Gold         [[9541, 11112, 6473, 12097, 19790, 9822, 16925...
# player1_CS           [[6, 191, 4, 194, 254, 24, 212, 21, 211, 216, ...
# player1_Role               [[NONE, SOLO, DUO_SUPPORT, DUO_CARRY, DUO]]
# player1_Lane                           [[JUNGLE, TOP, BOTTOM, MIDDLE]]
# player2_ChampionID   [[157, 18, 58, 21, 36, 114, 267, 103, 64, 235,...
# player2_Kills        [[1, 11, 5, 4, 7, 3, 0, 12, 8, 9, 6, 2, 21, 13...
# player2_Deaths       [[9, 10, 7, 4, 6, 1, 2, 8, 5, 3, 11, 12, 13, 1...
# player2_Assists      [[0, 6, 2, 5, 19, 22, 12, 7, 3, 8, 16, 10, 13,...
# player2_Gold         [[8149, 15701, 11842, 10230, 16895, 9131, 8901...
# player2_CS           [[165, 191, 171, 169, 84, 187, 26, 157, 28, 12...
# player2_Role               [[SOLO, DUO_CARRY, NONE, DUO_SUPPORT, DUO]]
# player2_Lane                           [[TOP, BOTTOM, JUNGLE, MIDDLE]]
# player3_ChampionID   [[69, 25, 222, 48, 119, 777, 22, 37, 8, 54, 15...
# player3_Kills        [[2, 4, 9, 0, 25, 5, 6, 7, 1, 29, 3, 11, 14, 2...
# player3_Deaths       [[6, 9, 0, 8, 5, 13, 11, 16, 3, 2, 7, 4, 10, 1...
# player3_Assists      [[1, 13, 5, 4, 0, 14, 15, 9, 11, 3, 12, 23, 17...
# player3_Gold         [[8444, 12091, 13794, 10608, 5929, 9560, 24168...
# player3_CS           [[180, 79, 166, 202, 0, 203, 262, 178, 82, 151...
# player3_Role               [[SOLO, DUO_SUPPORT, DUO_CARRY, DUO, NONE]]
# player3_Lane                           [[MIDDLE, BOTTOM, TOP, JUNGLE]]
# player4_ChampionID   [[236, 5, 60, 63, 145, 235, 245, 154, 99, 121,...
# player4_Kills        [[6, 17, 5, 1, 16, 3, 9, 2, 4, 10, 0, 13, 15, ...
# player4_Deaths       [[14, 11, 7, 8, 12, 2, 5, 3, 6, 10, 4, 9, 13, ...
# player4_Assists      [[6, 2, 8, 13, 19, 17, 11, 7, 9, 3, 12, 14, 5,...
# player4_Gold         [[9993, 17685, 10269, 6012, 18274, 6298, 13264...
# player4_CS           [[141, 163, 16, 12, 211, 20, 102, 32, 60, 10, ...
# player4_Role               [[DUO_CARRY, SOLO, NONE, DUO_SUPPORT, DUO]]
# player4_Lane                           [[BOTTOM, MIDDLE, JUNGLE, TOP]]
# player5_ChampionID   [[235, 20, 13, 254, 99, 245, 23, 164, 92, 555,...
# player5_Kills        [[5, 4, 7, 3, 17, 14, 12, 2, 0, 9, 1, 6, 10, 1...
# player5_Deaths       [[10, 14, 9, 6, 11, 5, 15, 3, 2, 4, 7, 8, 12, ...
# player5_Assists      [[7, 13, 4, 16, 3, 6, 9, 11, 15, 1, 5, 18, 8, ...
# player5_Gold         [[8070, 11877, 11941, 7893, 15426, 7368, 14766...
# player5_CS           [[34, 24, 177, 16, 85, 123, 229, 137, 184, 43,...
# player5_Role               [[DUO_SUPPORT, NONE, SOLO, DUO, DUO_CARRY]]
# player5_Lane                           [[BOTTOM, JUNGLE, MIDDLE, TOP]]
# player6_ChampionID   [[7, 55, 117, 56, 516, 350, 30, 131, 141, 164,...
# player6_Kills        [[8, 11, 2, 6, 13, 1, 20, 9, 0, 4, 10, 16, 12,...
# player6_Deaths       [[1, 9, 3, 4, 6, 2, 11, 10, 7, 5, 8, 13, 15, 1...
# player6_Assists      [[5, 13, 21, 8, 17, 10, 1, 4, 12, 7, 20, 18, 1...
# player6_Gold         [[11053, 18564, 9231, 12287, 17926, 6944, 1851...
# player6_CS           [[173, 239, 18, 33, 242, 24, 218, 144, 28, 4, ...
# player6_Role               [[SOLO, DUO_SUPPORT, NONE, DUO_CARRY, DUO]]
# player6_Lane                           [[MIDDLE, BOTTOM, JUNGLE, TOP]]
# player7_ChampionID   [[79, 28, 555, 51, 77, 81, 89, 145, 17, 1, 43,...
# player7_Kills        [[6, 16, 26, 8, 1, 3, 9, 4, 7, 2, 5, 0, 10, 19...
# player7_Deaths       [[3, 7, 5, 4, 16, 10, 6, 9, 11, 8, 2, 13, 14, ...
# player7_Assists      [[5, 16, 10, 12, 3, 4, 22, 6, 1, 11, 7, 2, 19,...
# player7_Gold         [[10060, 15617, 24149, 10913, 13746, 11010, 97...
# player7_CS           [[146, 39, 107, 167, 16, 206, 30, 177, 193, 19...
# player7_Role               [[SOLO, NONE, DUO_CARRY, DUO_SUPPORT, DUO]]
# player7_Lane                           [[TOP, JUNGLE, MIDDLE, BOTTOM]]
# player8_ChampionID   [[16, 39, 134, 4, 67, 61, 154, 32, 114, 81, 48...
# player8_Kills        [[3, 8, 2, 9, 7, 12, 18, 1, 4, 6, 0, 13, 5, 14...
# player8_Deaths       [[5, 7, 6, 4, 12, 10, 3, 8, 1, 13, 2, 11, 9, 1...
# player8_Assists      [[23, 10, 8, 9, 19, 4, 6, 7, 13, 17, 5, 3, 15,...
# player8_Gold         [[9527, 15070, 10301, 12580, 11470, 9144, 1432...
# player8_CS           [[21, 249, 176, 160, 139, 169, 48, 34, 134, 55...
# player8_Role               [[DUO_SUPPORT, SOLO, DUO_CARRY, DUO, NONE]]
# player8_Lane                           [[BOTTOM, TOP, MIDDLE, JUNGLE]]
# player9_ChampionID   [[81, 412, 72, 37, 69, 23, 131, 777, 201, 103,...
# player9_Kills        [[17, 9, 8, 1, 7, 5, 0, 13, 3, 6, 2, 12, 4, 11...
# player9_Deaths       [[5, 7, 6, 3, 12, 11, 4, 2, 8, 14, 9, 1, 13, 1...
# player9_Assists      [[10, 25, 17, 7, 5, 1, 3, 8, 2, 11, 16, 13, 6,...
# player9_Gold         [[14354, 13086, 13849, 8091, 14561, 11130, 169...
# player9_CS           [[168, 57, 16, 18, 188, 181, 230, 165, 33, 140...
# player9_Role               [[DUO_CARRY, DUO_SUPPORT, NONE, SOLO, DUO]]
# player9_Lane                           [[BOTTOM, JUNGLE, MIDDLE, TOP]]
# player10_ChampionID  [[28, 236, 8, 68, 235, 120, 122, 101, 103, 21,...
# player10_Kills       [[8, 13, 4, 14, 2, 11, 20, 3, 7, 12, 1, 6, 5, ...
# player10_Deaths      [[4, 7, 6, 5, 13, 1, 2, 10, 11, 3, 9, 12, 0, 8...
# player10_Assists     [[9, 16, 18, 7, 10, 8, 6, 3, 2, 5, 22, 13, 1, ...
# player10_Gold        [[10883, 17485, 12526, 13526, 10251, 13446, 22...
# player10_CS          [[17, 211, 173, 135, 65, 51, 265, 20, 170, 25,...
# player10_Role              [[NONE, DUO_CARRY, SOLO, DUO, DUO_SUPPORT]]
# player10_Lane                          [[JUNGLE, BOTTOM, TOP, MIDDLE]]
#
#                      Skewness
# MatchID             -0.078463
# GameDuration         0.946268
# Blue_Won                  NaN
# Blue_KillsTower     -0.113294
# Blue_KillsInhib      1.232648
# Blue_KillsBaron      0.994564
# Blue_KillsDragon     0.047424
# Purp_KillsTower     -0.141165
# Purp_KillsInhib      1.193154
# Purp_KillsBaron      0.900077
# Purp_KillsDragon    -0.024777
# player1_ChampionID   2.030605
# player1_Kills        1.141965
# player1_Deaths       0.480368
# player1_Assists      1.048801
# player1_Gold         0.617578
# player1_CS           0.053804
# player1_Role              NaN
# player1_Lane              NaN
# player2_ChampionID   2.093022
# player2_Kills        1.196024
# player2_Deaths       0.436366
# player2_Assists      1.016982
# player2_Gold         0.677193
# player2_CS           0.075958
# player2_Role              NaN
# player2_Lane              NaN
# player3_ChampionID   2.081484
# player3_Kills        1.169685
# player3_Deaths       0.450801
# player3_Assists      1.016925
# player3_Gold         0.648925
# player3_CS           0.046340
# player3_Role              NaN
# player3_Lane              NaN
# player4_ChampionID   2.081362
# player4_Kills        1.130198
# player4_Deaths       0.474618
# player4_Assists      1.039271
# player4_Gold         0.627343
# player4_CS           0.077846
# player4_Role              NaN
# player4_Lane              NaN
# player5_ChampionID   2.110234
# player5_Kills        1.149673
# player5_Deaths       0.458737
# player5_Assists      1.033781
# player5_Gold         0.613805
# player5_CS           0.053096
# player5_Role              NaN
# player5_Lane              NaN
# player6_ChampionID   2.112297
# player6_Kills        1.074798
# player6_Deaths       0.457739
# player6_Assists      1.045775
# player6_Gold         0.583886
# player6_CS           0.046486
# player6_Role              NaN
# player6_Lane              NaN
# player7_ChampionID   2.120928
# player7_Kills        1.122920
# player7_Deaths       0.444070
# player7_Assists      1.023094
# player7_Gold         0.623282
# player7_CS           0.085636
# player7_Role              NaN
# player7_Lane              NaN
# player8_ChampionID   2.104901
# player8_Kills        1.106827
# player8_Deaths       0.448752
# player8_Assists      0.997745
# player8_Gold         0.603359
# player8_CS           0.057836
# player8_Role              NaN
# player8_Lane              NaN
# player9_ChampionID   2.100161
# player9_Kills        1.185159
# player9_Deaths       0.495968
# player9_Assists      1.068018
# player9_Gold         0.613548
# player9_CS           0.066457
# player9_Role              NaN
# player9_Lane              NaN
# player10_ChampionID  2.125872
# player10_Kills       1.112407
# player10_Deaths      0.445601
# player10_Assists     1.075564
# player10_Gold        0.598966
# player10_CS          0.023263
# player10_Role             NaN
# player10_Lane             NaN

# %%
data = data.drop('MatchID', axis=1)

# String to bool
data['Blue_Won'] = np.where(data['Blue_Won']=='Fail', 0, 1)

# Merging "Role" and "Lane" columns
for r_col, l_col in zip([i for i in data.columns if i[-4:]=='Role'],
                        [i for i in data.columns if i[-4:]=='Lane']):
    data[r_col] = data[r_col] + ' ' + data[l_col]
    data = data.drop(l_col, axis=1)
    
# Droping rows with wrongly labeled roles
to_drop = ['DUO TOP', 'DUO MIDDLE', 'DUO_SUPPORT MIDDLE', 'DUO_SUPPORT TOP', 
           'DUO_CARRY MIDDLE', 'SOLO BOTTOM', 'DUO BOTTOM']

for col in [i for i in data.columns if i[-4:]=='Role']:
    for role in to_drop:
        data = data.loc[data[col]!=role]
        
data = data.reset_index(drop=True)

# %% [markdown]
# &emsp;We are going to be extra careful about how we handle roles this time. I didn't want to feature engineer lane-to-lane comparison features last time but that seems more likely now given the tight feature space we are given by the API where we are getting our test data from.

# %%
# Renaming roles
roles = [['NONE JUNGLE', 'Jungle'], ['SOLO TOP', 'Top'], ['SOLO MIDDLE', 'Mid'],
         ['DUO_CARRY BOTTOM', 'Adc'], ['DUO_SUPPORT BOTTOM', 'Support']]

for col in [i for i in data.columns if i[-4:]=='Role']:
    for old, new in roles:
        data[col] = np.where(data[col]==old, new, data[col])

# %% [markdown]
# ### Aligning postitions with columns

# %%
# Checking which games have valid team compositions
# Team1: Adc, Jungle, etc... Team2: -||-
valid_roles = ['Adc', 'Jungle', 'Mid', 'Support', 'Top']

player_data = data[[i for i in data.columns if i[:6]=='player']]

team1_okteams = []

team1 = player_data[['player'+str(i)+'_Role' for i in range(1, 6)]]
for idx, row in team1.iterrows():
    roles = list(row)
    roles.sort()
    if valid_roles == roles:
        team1_okteams.append(idx)
        
team2_okteams = []

team2 = player_data[['player'+str(i)+'_Role' for i in range(6, 11)]]
for idx, row in team2.iterrows():
    roles = list(row)
    roles.sort()
    if valid_roles == roles:
        team2_okteams.append(idx)
        
ok_games = [i for i in team1_okteams if i in team2_okteams]

data = data.iloc[[i for i in data.index if i in ok_games]]
data = data.reset_index(drop=True)

# %%
# Sorting dataframes so I can take the difference of players
# Iterative and slow code

teams = [data.iloc[:, 10:45], data.iloc[:, 45:]]

# Renaming columns
for idx in range(2):
    for start, role in zip(range(0, 35, 7), valid_roles):
        for col in teams[idx].iloc[:, start:start + 7].columns:
            teams[idx] = teams[idx].rename(columns={col:role+'_'+col.split('_')[1]})

# Sorting
for idx in range(2):
    to_concat = []
    for col in valid_roles:
        curr_data = pd.DataFrame(columns=[i for i in teams[idx].columns if col in i])

        for role in valid_roles:
            curr_cols = teams[idx][[i for i in teams[idx].columns if role in i]]
            curr_cols = curr_cols.loc[curr_cols.iloc[:, -1]==col] # Rows with Role
            curr_cols.columns = curr_data.columns # Renaming for concat
        
            curr_data = pd.concat([curr_data, curr_cols], axis=0)
            
        curr_data.sort_index(inplace=True)
        to_concat.append(curr_data)

    teams[idx] = pd.concat(to_concat, axis=1)
    
# Dropping the Role Columns and converting obj type
for idx in range(2):
    teams[idx] = teams[idx].drop([i for i in teams[idx].columns if 'Role' in i],
                                  axis=1).astype('float64')
    
# Indicating Blue and Purple team column names in players
teams[0].columns = ['Blue_'+i for i in teams[0].columns]
teams[1].columns = ['Purp_'+i for i in teams[1].columns]

# %%
# Merging data
# Aggregate teams' features

team_features = pd.DataFrame()

for i, team in enumerate(['Blue', 'Purp']):
    curr_data = teams[i]
    
    team_features[team+'_Kills'] = teams[i][[i for i in teams[i].columns if i[-5:]=='Kills']].sum(axis=1)
    team_features[team+'_Assists'] = teams[i][[i for i in teams[i].columns if i[-7:]=='Assists']].sum(axis=1)
    team_features[team+'_Gold'] = teams[i][[i for i in teams[i].columns if i[-4:]=='Gold']].sum(axis=1)


data = pd.concat([data.iloc[:, :10], team_features,teams[0], teams[1]], axis=1)

# %% [markdown]
# ### Trimming

# %%
team_trim = [['_KillsInhib', 6], ['_KillsBaron', 3], ['_KillsDragon', 6],
           ['_Kills', 66], ['_Gold', 90000]]

for team in ['Blue', 'Purp']:
    for col, threshold in team_trim:
        data = data.loc[data[team+col]<threshold]
        
player_trim = [['Kills', 20], ['Deaths', 15]]

for col, threshold in player_trim:
    for full_col in [i for i in data.columns if i[-len(col):]==col and len(i.split('_'))==3]:
        data = data.loc[data[full_col]<threshold]
        
data = data.reset_index(drop=True)

# %% [markdown]
# ### Export

# %%
data.to_csv('data.csv', index=False)

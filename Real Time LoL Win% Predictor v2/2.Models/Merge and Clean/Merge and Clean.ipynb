# %%
import numpy as np
import pandas as pd
import easydatascience as eds
import os
        
match_cols = ['MatchID', 'GameDuration', 'Blue_Won', 'Blue_KillsTower', 
              'Blue_KillsInhib', 'Blue_KillsBaron', 'Blue_KillsDragon', 
              'Purp_KillsTower', 'Purp_KillsInhib', 'Purp_KillsBaron',
              'Purp_KillsDragon']

base_player_cols = ['ChampionID', 'Kills', 'Deaths', 'Assists', 'Gold', 'CS', 'Role',
                    'Lane']

# Generating column names for 10 players
player_cols = []

for i in range(1, 11):
    curr_player = 'player' + str(i)
    curr_list = [curr_player + '_' + col for col in base_player_cols]
    player_cols += curr_list
    
column_names = match_cols + player_cols

# Reading CSVs
datas = []
csvs = [i for i in os.listdir() if i[-4:]=='.csv']

for csv in csvs:
    datas.append(pd.read_csv(csv, names=column_names))
    
data = pd.concat(datas)

data = data.reset_index(drop=True)

pd.set_option('max_rows', eds.look(data).shape[0])
eds.look(data)
# Out:
#                       Types  Counts  Distincts  Nulls  Missing ratio (%)  \
# MatchID              object   64486      64374      0                0.0
# GameDuration         object   64486       1603      0                0.0
# Blue_Won             object   64486          2      0                0.0
# Blue_KillsTower      object   64486         12      0                0.0
# Blue_KillsInhib      object   64486         10      0                0.0
# Blue_KillsBaron      object   64486          5      0                0.0
# Blue_KillsDragon     object   64486          8      0                0.0
# Purp_KillsTower      object   64486         12      0                0.0
# Purp_KillsInhib      object   64486         12      0                0.0
# Purp_KillsBaron      object   64486          5      0                0.0
# Purp_KillsDragon     object   64486          8      0                0.0
# player1_ChampionID   object   64486        151      0                0.0
# player1_Kills        object   64486         43      0                0.0
# player1_Deaths       object   64486         27      0                0.0
# player1_Assists      object   64486         46      0                0.0
# player1_Gold         object   64486      14164      0                0.0
# player1_CS           object   64486        369      0                0.0
# player1_Role         object   64486          5      0                0.0
# player1_Lane         object   64486          4      0                0.0
# player2_ChampionID   object   64486        151      0                0.0
# player2_Kills        object   64486         46      0                0.0
# player2_Deaths       object   64486         28      0                0.0
# player2_Assists      object   64486         48      0                0.0
# player2_Gold         object   64486      14309      0                0.0
# player2_CS           object   64486        369      0                0.0
# player2_Role         object   64486          5      0                0.0
# player2_Lane         object   64486          4      0                0.0
# player3_ChampionID   object   64486        151      0                0.0
# player3_Kills        object   64486         41      0                0.0
# player3_Deaths       object   64486         27      0                0.0
# player3_Assists      object   64486         46      0                0.0
# player3_Gold         object   64486      14210      0                0.0
# player3_CS           object   64486        372      0                0.0
# player3_Role         object   64486          5      0                0.0
# player3_Lane         object   64486          4      0                0.0
# player4_ChampionID   object   64486        151      0                0.0
# player4_Kills        object   64486         43      0                0.0
# player4_Deaths       object   64486         27      0                0.0
# player4_Assists      object   64486         45      0                0.0
# player4_Gold         object   64486      14246      0                0.0
# player4_CS           object   64486        373      0                0.0
# player4_Role         object   64486          5      0                0.0
# player4_Lane         object   64486          4      0                0.0
# player5_ChampionID   object   64486        151      0                0.0
# player5_Kills        object   64486         42      0                0.0
# player5_Deaths       object   64486         26      0                0.0
# player5_Assists      object   64486         45      0                0.0
# player5_Gold         object   64486      14190      0                0.0
# player5_CS           object   64486        366      0                0.0
# player5_Role         object   64486          5      0                0.0
# player5_Lane         object   64486          4      0                0.0
# player6_ChampionID   object   64486        151      0                0.0
# player6_Kills        object   64486         42      0                0.0
# player6_Deaths       object   64486         24      0                0.0
# player6_Assists      object   64486         46      0                0.0
# player6_Gold         object   64486      14274      0                0.0
# player6_CS           object   64486        377      0                0.0
# player6_Role         object   64486          5      0                0.0
# player6_Lane         object   64486          4      0                0.0
# player7_ChampionID   object   64486        151      0                0.0
# player7_Kills        object   64486         42      0                0.0
# player7_Deaths       object   64486         25      0                0.0
# player7_Assists      object   64486         47      0                0.0
# player7_Gold         object   64486      14398      0                0.0
# player7_CS           object   64486        369      0                0.0
# player7_Role         object   64486          5      0                0.0
# player7_Lane         object   64486          4      0                0.0
# player8_ChampionID   object   64486        151      0                0.0
# player8_Kills        object   64486         39      0                0.0
# player8_Deaths       object   64486         26      0                0.0
# player8_Assists      object   64486         45      0                0.0
# player8_Gold         object   64486      14319      0                0.0
# player8_CS           object   64486        379      0                0.0
# player8_Role         object   64486          5      0                0.0
# player8_Lane         object   64486          4      0                0.0
# player9_ChampionID   object   64486        151      0                0.0
# player9_Kills        object   64486         43      0                0.0
# player9_Deaths       object   64486         25      0                0.0
# player9_Assists      object   64486         47      0                0.0
# player9_Gold         object   64486      14327      0                0.0
# player9_CS           object   64486        377      0                0.0
# player9_Role         object   64486          5      0                0.0
# player9_Lane         object   64486          4      0                0.0
# player10_ChampionID  object   64486        151      0                0.0
# player10_Kills       object   64486         40      0                0.0
# player10_Deaths      object   64486         23      0                0.0
# player10_Assists     object   64486         48      0                0.0
# player10_Gold        object   64486      14302      0                0.0
# player10_CS          object   64486        370      0                0.0
# player10_Role        object   64486          5      0                0.0
# player10_Lane        object   64486          4      0                0.0
#
#                                                                Uniques  \
# MatchID              [[2596338792, 2595754987, 2595751884, 25957596...
# GameDuration         [[1797, 2340, 2114, 2047, 2454, 1886, 1616, 16...
# Blue_Won                                                 [[Fail, Win]]
# Blue_KillsTower               [[6, 4, 3, 5, 9, 1, 8, 10, 2, 7, 11, 0]]
# Blue_KillsInhib                       [[0, 2, 3, 1, 4, 6, 5, 8, 7, 9]]
# Blue_KillsBaron                                      [[0, 3, 1, 2, 4]]
# Blue_KillsDragon                            [[2, 1, 0, 3, 4, 5, 6, 7]]
# Purp_KillsTower               [[6, 10, 7, 2, 8, 3, 5, 9, 4, 11, 0, 1]]
# Purp_KillsInhib               [[2, 1, 3, 0, 5, 4, 6, 8, 7, 9, 10, 11]]
# Purp_KillsBaron                                      [[0, 1, 2, 3, 4]]
# Purp_KillsDragon                            [[2, 4, 3, 1, 5, 0, 6, 7]]
# player1_ChampionID   [[5, 8, 51, 24, 875, 238, 141, 145, 19, 115, 2...
# player1_Kills        [[4, 5, 3, 6, 7, 12, 14, 9, 1, 11, 21, 2, 28, ...
# player1_Deaths       [[11, 14, 10, 7, 8, 5, 4, 12, 6, 16, 13, 1, 3,...
# player1_Assists      [[6, 5, 7, 2, 23, 8, 13, 4, 3, 15, 12, 22, 9, ...
# player1_Gold         [[9009, 14150, 11024, 12135, 13801, 13356, 129...
# player1_CS           [[16, 190, 171, 169, 58, 163, 45, 179, 187, 33...
# player1_Role               [[NONE, SOLO, DUO_CARRY, DUO, DUO_SUPPORT]]
# player1_Lane                           [[JUNGLE, MIDDLE, BOTTOM, TOP]]
# player2_ChampionID   [[112, 113, 31, 111, 23, 107, 54, 36, 164, 12,...
# player2_Kills        [[6, 4, 11, 1, 16, 8, 0, 5, 9, 3, 7, 15, 13, 1...
# player2_Deaths       [[7, 8, 10, 11, 5, 9, 3, 2, 6, 14, 1, 12, 4, 1...
# player2_Assists      [[6, 8, 4, 12, 15, 20, 10, 7, 14, 5, 9, 2, 1, ...
# player2_Gold         [[9351, 14843, 15984, 8315, 19552, 11693, 7008...
# player2_CS           [[125, 36, 49, 35, 226, 33, 88, 118, 124, 34, ...
# player2_Role               [[SOLO, NONE, DUO_SUPPORT, DUO_CARRY, DUO]]
# player2_Lane                           [[MIDDLE, JUNGLE, BOTTOM, TOP]]
# player3_ChampionID   [[25, 114, 432, 145, 13, 7, 90, 81, 24, 157, 1...
# player3_Kills        [[0, 10, 1, 8, 14, 4, 6, 2, 13, 18, 3, 12, 7, ...
# player3_Deaths       [[9, 6, 13, 5, 8, 3, 11, 7, 10, 14, 2, 17, 4, ...
# player3_Assists      [[17, 9, 14, 6, 15, 11, 4, 0, 8, 13, 3, 7, 12,...
# player3_Gold         [[8833, 16481, 8368, 14989, 17721, 11062, 9443...
# player3_CS           [[35, 167, 27, 234, 203, 175, 144, 106, 16, 18...
# player3_Role               [[DUO_SUPPORT, SOLO, DUO_CARRY, NONE, DUO]]
# player3_Lane                           [[BOTTOM, TOP, MIDDLE, JUNGLE]]
# player4_ChampionID   [[51, 111, 13, 777, 201, 89, 29, 2, 497, 25, 1...
# player4_Kills        [[13, 3, 4, 0, 9, 21, 2, 1, 10, 8, 6, 7, 16, 1...
# player4_Deaths       [[6, 13, 8, 7, 3, 10, 12, 9, 15, 5, 14, 11, 1,...
# player4_Assists      [[4, 19, 6, 2, 31, 10, 12, 3, 11, 14, 20, 1, 5...
# player4_Gold         [[16314, 10535, 11447, 12654, 10922, 8007, 106...
# player4_CS           [[176, 30, 160, 234, 35, 27, 154, 50, 131, 14,...
# player4_Role               [[DUO_CARRY, DUO_SUPPORT, SOLO, NONE, DUO]]
# player4_Lane                           [[BOTTOM, MIDDLE, JUNGLE, TOP]]
# player5_ChampionID   [[114, 360, 98, 64, 81, 22, 80, 99, 145, 48, 3...
# player5_Kills        [[1, 16, 5, 2, 18, 6, 4, 0, 10, 8, 3, 14, 11, ...
# player5_Deaths       [[10, 16, 11, 5, 8, 7, 6, 2, 1, 14, 9, 4, 13, ...
# player5_Assists      [[3, 11, 8, 6, 13, 17, 19, 9, 4, 5, 22, 16, 7,...
# player5_Gold         [[9334, 19953, 11903, 9606, 20358, 14253, 7353...
# player5_CS           [[155, 226, 167, 26, 276, 172, 22, 47, 145, 21...
# player5_Role               [[SOLO, DUO_CARRY, NONE, DUO, DUO_SUPPORT]]
# player5_Lane                           [[TOP, BOTTOM, JUNGLE, MIDDLE]]
# player6_ChampionID   [[86, 34, 555, 103, 5, 98, 875, 238, 360, 236,...
# player6_Kills        [[9, 11, 13, 7, 3, 6, 15, 4, 2, 10, 5, 17, 21,...
# player6_Deaths       [[3, 7, 9, 19, 4, 2, 5, 8, 11, 6, 10, 1, 12, 1...
# player6_Assists      [[11, 17, 5, 10, 9, 14, 8, 12, 20, 1, 30, 2, 6...
# player6_Gold         [[13247, 15078, 16571, 11909, 12145, 12417, 10...
# player6_CS           [[193, 157, 153, 145, 48, 164, 142, 152, 217, ...
# player6_Role               [[SOLO, NONE, DUO_CARRY, DUO_SUPPORT, DUO]]
# player6_Lane                           [[MIDDLE, TOP, JUNGLE, BOTTOM]]
# player7_ChampionID   [[24, 150, 350, 98, 36, 157, 245, 51, 29, 6, 6...
# player7_Kills        [[19, 4, 2, 17, 14, 16, 3, 8, 6, 5, 10, 9, 22,...
# player7_Deaths       [[4, 8, 1, 5, 7, 6, 9, 11, 10, 12, 3, 13, 2, 1...
# player7_Assists      [[9, 11, 37, 23, 13, 8, 6, 5, 7, 10, 19, 4, 18...
# player7_Gold         [[15512, 13738, 11518, 10274, 19093, 15830, 16...
# player7_CS           [[68, 196, 4, 140, 158, 221, 161, 19, 116, 215...
# player7_Role               [[NONE, SOLO, DUO_SUPPORT, DUO, DUO_CARRY]]
# player7_Lane                           [[JUNGLE, TOP, BOTTOM, MIDDLE]]
# player8_ChampionID   [[44, 63, 360, 141, 157, 106, 102, 82, 777, 25...
# player8_Kills        [[4, 8, 19, 9, 12, 6, 2, 11, 7, 10, 14, 17, 16...
# player8_Deaths       [[5, 11, 2, 4, 6, 8, 3, 10, 7, 9, 1, 13, 14, 1...
# player8_Assists      [[25, 31, 8, 13, 15, 10, 4, 2, 11, 9, 16, 6, 1...
# player8_Gold         [[8521, 13990, 17401, 13012, 18682, 12279, 849...
# player8_CS           [[58, 39, 221, 95, 258, 22, 24, 170, 110, 151,...
# player8_Role               [[SOLO, DUO_SUPPORT, DUO_CARRY, NONE, DUO]]
# player8_Lane                           [[TOP, BOTTOM, JUNGLE, MIDDLE]]
# player9_ChampionID   [[222, 106, 141, 81, 44, 37, 89, 360, 102, 555...
# player9_Kills        [[9, 17, 12, 22, 1, 4, 3, 16, 5, 23, 19, 13, 2...
# player9_Deaths       [[7, 5, 10, 11, 8, 3, 6, 4, 9, 13, 2, 15, 14, ...
# player9_Assists      [[6, 20, 14, 13, 15, 24, 18, 3, 7, 8, 11, 33, ...
# player9_Gold         [[12361, 19456, 14773, 18823, 9126, 9608, 7398...
# player9_CS           [[183, 92, 52, 210, 37, 4, 29, 224, 48, 38, 20...
# player9_Role               [[DUO_CARRY, NONE, DUO_SUPPORT, SOLO, DUO]]
# player9_Lane                           [[BOTTOM, JUNGLE, MIDDLE, TOP]]
# player10_ChampionID  [[267, 202, 105, 350, 235, 360, 99, 32, 517, 5...
# player10_Kills       [[2, 17, 6, 4, 5, 1, 11, 7, 8, 14, 10, 9, 16, ...
# player10_Deaths      [[5, 7, 4, 8, 11, 1, 9, 10, 3, 12, 13, 2, 6, 1...
# player10_Assists     [[26, 21, 7, 32, 13, 12, 6, 9, 18, 15, 3, 17, ...
# player10_Gold        [[8347, 17657, 9920, 9850, 13547, 10882, 8413,...
# player10_CS          [[20, 192, 128, 6, 177, 142, 121, 40, 25, 180,...
# player10_Role              [[DUO_SUPPORT, DUO_CARRY, SOLO, NONE, DUO]]
# player10_Lane                          [[BOTTOM, MIDDLE, JUNGLE, TOP]]
#
#                      Skewness
# MatchID             -0.110100
# GameDuration         0.942415
# Blue_Won                  NaN
# Blue_KillsTower     -0.101427
# Blue_KillsInhib      1.243947
# Blue_KillsBaron      1.005399
# Blue_KillsDragon     0.044457
# Purp_KillsTower     -0.158061
# Purp_KillsInhib      1.187502
# Purp_KillsBaron      0.881076
# Purp_KillsDragon    -0.025295
# player1_ChampionID   2.088131
# player1_Kills        1.165880
# player1_Deaths       0.441485
# player1_Assists      1.026506
# player1_Gold         0.618143
# player1_CS           0.062462
# player1_Role              NaN
# player1_Lane              NaN
# player2_ChampionID   2.130543
# player2_Kills        1.207451
# player2_Deaths       0.428767
# player2_Assists      1.037549
# player2_Gold         0.669121
# player2_CS           0.087267
# player2_Role              NaN
# player2_Lane              NaN
# player3_ChampionID   2.105900
# player3_Kills        1.153701
# player3_Deaths       0.429363
# player3_Assists      1.012850
# player3_Gold         0.648147
# player3_CS           0.065482
# player3_Role              NaN
# player3_Lane              NaN
# player4_ChampionID   2.105177
# player4_Kills        1.147736
# player4_Deaths       0.435740
# player4_Assists      1.018522
# player4_Gold         0.609876
# player4_CS           0.081023
# player4_Role              NaN
# player4_Lane              NaN
# player5_ChampionID   2.124713
# player5_Kills        1.141455
# player5_Deaths       0.446275
# player5_Assists      1.023415
# player5_Gold         0.613884
# player5_CS           0.042433
# player5_Role              NaN
# player5_Lane              NaN
# player6_ChampionID   2.162198
# player6_Kills        1.112402
# player6_Deaths       0.434945
# player6_Assists      1.056905
# player6_Gold         0.597379
# player6_CS           0.040396
# player6_Role              NaN
# player6_Lane              NaN
# player7_ChampionID   2.144521
# player7_Kills        1.129072
# player7_Deaths       0.429679
# player7_Assists      1.028679
# player7_Gold         0.610351
# player7_CS           0.088248
# player7_Role              NaN
# player7_Lane              NaN
# player8_ChampionID   2.144203
# player8_Kills        1.130750
# player8_Deaths       0.455271
# player8_Assists      1.032967
# player8_Gold         0.609316
# player8_CS           0.074948
# player8_Role              NaN
# player8_Lane              NaN
# player9_ChampionID   2.150668
# player9_Kills        1.142325
# player9_Deaths       0.457670
# player9_Assists      1.046022
# player9_Gold         0.599475
# player9_CS           0.075485
# player9_Role              NaN
# player9_Lane              NaN
# player10_ChampionID  2.158114
# player10_Kills       1.099635
# player10_Deaths      0.428034
# player10_Assists     1.069421
# player10_Gold        0.593917
# player10_CS          0.042395
# player10_Role             NaN
# player10_Lane             NaN

# %%
data = data.drop('MatchID', axis=1)

# String to bool
data['Blue_Won'] = np.where(data['Blue_Won']=='Fail', 0, 1)

# Merging "Role" and "Lane" columns
for r_col, l_col in zip([i for i in data.columns if i[-4:]=='Role'],
                        [i for i in data.columns if i[-4:]=='Lane']):
    data[r_col] = data[r_col] + ' ' + data[l_col]
    data = data.drop(l_col, axis=1)
    
# Droping rows with wrongly labeled roles
to_drop = ['DUO TOP', 'DUO MIDDLE', 'DUO_SUPPORT MIDDLE', 'DUO_SUPPORT TOP', 
           'DUO_CARRY MIDDLE', 'SOLO BOTTOM', 'DUO BOTTOM']

for col in [i for i in data.columns if i[-4:]=='Role']:
    for role in to_drop:
        data = data.loc[data[col]!=role]
        
data = data.reset_index(drop=True)

# %% [markdown]
# &emsp;We are going to be extra careful about how we handle roles this time. I didn't want to feature engineer lane-to-lane comparison features last time but that seems more likely now given the tight feature space we are given by the API where we are getting our test data from.

# %%
# Renaming roles
roles = [['NONE JUNGLE', 'Jungle'], ['SOLO TOP', 'Top'], ['SOLO MIDDLE', 'Mid'],
         ['DUO_CARRY BOTTOM', 'Adc'], ['DUO_SUPPORT BOTTOM', 'Support']]

for col in [i for i in data.columns if i[-4:]=='Role']:
    for old, new in roles:
        data[col] = np.where(data[col]==old, new, data[col])

# %% [markdown]
# ### Aligning postitions with columns

# %%
# Checking which games have valid team compositions
# Team1: Adc, Jungle, etc... Team2: -||-
valid_roles = ['Adc', 'Jungle', 'Mid', 'Support', 'Top']

player_data = data[[i for i in data.columns if i[:6]=='player']]

team1_okteams = []

team1 = player_data[['player'+str(i)+'_Role' for i in range(1, 6)]]
for idx, row in team1.iterrows():
    roles = list(row)
    roles.sort()
    if valid_roles == roles:
        team1_okteams.append(idx)
        
team2_okteams = []

team2 = player_data[['player'+str(i)+'_Role' for i in range(6, 11)]]
for idx, row in team2.iterrows():
    roles = list(row)
    roles.sort()
    if valid_roles == roles:
        team2_okteams.append(idx)
        
ok_games = [i for i in team1_okteams if i in team2_okteams]

data = data.iloc[[i for i in data.index if i in ok_games]]
data = data.reset_index(drop=True)

# %%
# Sorting dataframes so I can take the difference of players
# Iterative and slow code

teams = [data.iloc[:, 10:45], data.iloc[:, 45:]]

# Renaming columns
for idx in range(2):
    for start, role in zip(range(0, 35, 7), valid_roles):
        for col in teams[idx].iloc[:, start:start + 7].columns:
            teams[idx] = teams[idx].rename(columns={col:role+'_'+col.split('_')[1]})

# Sorting
for idx in range(2):
    to_concat = []
    for col in valid_roles:
        curr_data = pd.DataFrame(columns=[i for i in teams[idx].columns if col in i])

        for role in valid_roles:
            curr_cols = teams[idx][[i for i in teams[idx].columns if role in i]]
            curr_cols = curr_cols.loc[curr_cols.iloc[:, -1]==col] # Rows with Role
            curr_cols.columns = curr_data.columns # Renaming for concat
        
            curr_data = pd.concat([curr_data, curr_cols], axis=0)
            
        curr_data.sort_index(inplace=True)
        to_concat.append(curr_data)

    teams[idx] = pd.concat(to_concat, axis=1)
    
# Dropping the Role Columns and converting obj type
for idx in range(2):
    teams[idx] = teams[idx].drop([i for i in teams[idx].columns if 'Role' in i],
                                  axis=1).astype('float64')
    
# Indicating Blue and Purple team column names in players
teams[0].columns = ['Blue_'+i for i in teams[0].columns]
teams[1].columns = ['Purp_'+i for i in teams[1].columns]

# %%
# Merging data
# Aggregate teams' features

team_features = pd.DataFrame()

for i, team in enumerate(['Blue', 'Purp']):
    curr_data = teams[i]
    
    team_features[team+'_Kills'] = teams[i][[i for i in teams[i].columns if i[-5:]=='Kills']].sum(axis=1)
    team_features[team+'_Assists'] = teams[i][[i for i in teams[i].columns if i[-7:]=='Assists']].sum(axis=1)
    team_features[team+'_Gold'] = teams[i][[i for i in teams[i].columns if i[-4:]=='Gold']].sum(axis=1)


data = pd.concat([data.iloc[:, :10], team_features,teams[0], teams[1]], axis=1)

# %% [markdown]
# ### Trimming

# %%
team_trim = [['_KillsInhib', 6], ['_KillsBaron', 3], ['_KillsDragon', 6],
           ['_Kills', 66], ['_Gold', 90000]]

for team in ['Blue', 'Purp']:
    for col, threshold in team_trim:
        data = data.loc[data[team+col]<threshold]
        
player_trim = [['Kills', 20], ['Deaths', 15]]

for col, threshold in player_trim:
    for full_col in [i for i in data.columns if i[-len(col):]==col and len(i.split('_'))==3]:
        data = data.loc[data[full_col]<threshold]
        
data = data.reset_index(drop=True)

# %% [markdown]
# ### Export

# %%
data.to_csv('data.csv', index=False)
